# %%
import pandas as pd
df_sales_records = pd.read_csv('/content/1000 Sales Records.csv')

df_sales_records
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
print(df_sales_records.info())
print(df_sales_records.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1000 non-null   object
#  1   Country         1000 non-null   object
#  2   Item Type       1000 non-null   object
#  3   Sales Channel   1000 non-null   object
#  4   Order Priority  1000 non-null   object
#  5   Order Date      1000 non-null   object
#  6   Order ID        1000 non-null   int64
#  7   Ship Date       1000 non-null   object
#  8   Units Sold      1000 non-null   int64
#  9   Unit Price      1000 non-null   float64
#  10  Unit Cost       1000 non-null   float64
#  11  Total Revenue   1000 non-null   float64
#  12  Total Cost      1000 non-null   float64
#  13  Total Profit    1000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 109.5+ KB
# None
# ...

# %%
print(df_sales_records.isnull().sum())
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
#Sales by Region
sales_by_region = df_sales_records.groupby('Region')['Total Revenue'].sum()

print(sales_by_region)
# Out:
# Region
# Asia                                 1.676748e+08
# Australia and Oceania                1.056896e+08
# Central America and the Caribbean    1.439976e+08
# Europe                               3.531675e+08
# Middle East and North Africa         1.751065e+08
# North America                        2.496160e+07
# Sub-Saharan Africa                   3.567243e+08
# Name: Total Revenue, dtype: float64

# %%
#Total Revenue by Country
total_revenue_by_country = df_sales_records.groupby('Country')['Total Revenue'].sum()

print(total_revenue_by_country)
# Out:
# Country
# Afghanistan      2843589.07
# Albania          9709899.27
# Algeria         10272591.44
# Andorra          7153122.97
# Angola          15643032.02
#                    ...
# Vatican City     1575379.28
# Vietnam         11668032.25
# Yemen           11813464.95
# Zambia           1954116.20
# Zimbabwe         6928978.02
# Name: Total Revenue, Length: 185, dtype: float64

# %%
#Average Profit by Item Type
average_profit_by_item_type = df_sales_records.groupby('Item Type')['Total Profit'].mean()

print(average_profit_by_item_type)
# Out:
# Item Type
# Baby Food          481082.775632
# Beverages           78285.270297
# Cereal             434818.783671
# Clothes            355888.356923
# Cosmetics          987748.515200
# Fruits              12226.446429
# Household          798500.054026
# Meat               299137.666667
# Office Supplies    630515.196629
# Personal Care      137030.384368
# Snacks             265710.245854
# Vegetables         306718.081237
# Name: Total Profit, dtype: float64

# %%
#Correlation Analysis
correlation_matrix = df_sales_records.select_dtypes(include=['number']).corr()

print(correlation_matrix)
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID       1.000000    0.010266   -0.033436  -0.035550      -0.022079
# Units Sold     0.010266    1.000000    0.004212   0.002574       0.527945
# Unit Price    -0.033436    0.004212    1.000000   0.986735       0.730752
# Unit Cost     -0.035550    0.002574    0.986735   1.000000       0.717999
# Total Revenue -0.022079    0.527945    0.730752   0.717999       1.000000
# Total Cost    -0.025629    0.479713    0.745538   0.753678       0.987779
# Total Profit  -0.007886    0.591957    0.572235   0.498156       0.881429
#
#                Total Cost  Total Profit
# Order ID        -0.025629     -0.007886
# Units Sold       0.479713      0.591957
# Unit Price       0.745538      0.572235
# Unit Cost        0.753678      0.498156
# Total Revenue    0.987779      0.881429
# Total Cost       1.000000      0.797041
# Total Profit     0.797041      1.000000

# %%
#Top 10 Orders by Total Revenue
top_10_orders = df_sales_records.nlargest(10, 'Total Revenue')

print(top_10_orders)
# Out:
#                                 Region                   Country  \
# 286                             Europe            Czech Republic
# 952              Australia and Oceania          Papua New Guinea
# 554                               Asia                  Mongolia
# 998                             Europe                   Finland
# 36                  Sub-Saharan Africa                 Swaziland
# 943                               Asia                    Bhutan
# 582  Central America and the Caribbean                      Cuba
# 238  Central America and the Caribbean                Costa Rica
# 976                 Sub-Saharan Africa  Central African Republic
# 311                      North America                 Greenland
#
#            Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 286        Household        Online              L   2/27/2010  494525372
# 952        Household        Online              M   3/14/2012  442214143
# ...

# %%
top_orders = df_sales_records.sort_values(by='Total Revenue', ascending=False).head(10)

print(top_orders)
# Out:
#                                 Region                   Country  \
# 286                             Europe            Czech Republic
# 952              Australia and Oceania          Papua New Guinea
# 554                               Asia                  Mongolia
# 998                             Europe                   Finland
# 36                  Sub-Saharan Africa                 Swaziland
# 943                               Asia                    Bhutan
# 582  Central America and the Caribbean                      Cuba
# 238  Central America and the Caribbean                Costa Rica
# 976                 Sub-Saharan Africa  Central African Republic
# 311                      North America                 Greenland
#
#            Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 286        Household        Online              L   2/27/2010  494525372
# 952        Household        Online              M   3/14/2012  442214143
# ...

# %%
#Orders with High Priority
high_priority_orders = df_sales_records[df_sales_records['Order Priority'] == 'H']

print(high_priority_orders)
# Out:
#                                 Region      Country      Item Type  \
# 4                   Sub-Saharan Africa         Chad         Fruits
# 5                               Europe      Armenia         Cereal
# 6                   Sub-Saharan Africa      Eritrea         Cereal
# 8    Central America and the Caribbean      Jamaica     Vegetables
# 9                Australia and Oceania         Fiji     Vegetables
# ..                                 ...          ...            ...
# 982                             Europe  Switzerland         Snacks
# 984                 Sub-Saharan Africa      Comoros  Personal Care
# 986                               Asia     Mongolia        Clothes
# 991                 Sub-Saharan Africa      Liberia         Cereal
# 996                             Europe      Georgia      Baby Food
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 4         Offline              H   8/16/2011  645713555   8/31/2011
# ...

# %%
#Average Sales
average_sales = df_sales_records['Total Revenue'].mean()

print(average_sales)
# Out:
# 1327321.84033

# %%
#number of orders per country
orders_per_country = df_sales_records.groupby('Country')['Order ID'].count()

print(orders_per_country)
# Out:
# Country
# Afghanistan      6
# Albania          8
# Algeria          5
# Andorra          7
# Angola           8
#                 ..
# Vatican City     4
# Vietnam          7
# Yemen            6
# Zambia           2
# Zimbabwe        10
# Name: Order ID, Length: 185, dtype: int64

# %%
orders_by_country = df_sales_records['Country'].value_counts()
print(orders_by_country)
# Out:
# Country
# Cuba              11
# Czech Republic    10
# Bahrain           10
# Zimbabwe          10
# Malaysia          10
#                   ..
# Denmark            2
# The Gambia         2
# Kosovo             1
# Malta              1
# Cameroon           1
# Name: count, Length: 185, dtype: int64

# %%
#Filter data for a specific region
region_data_filter = df_sales_records[df_sales_records['Region'] == 'North America']

print(region_data_filter)
# Out:
#             Region                   Country        Item Type Sales Channel  \
# 1    North America                    Canada       Vegetables        Online
# 17   North America                 Greenland        Beverages        Online
# 27   North America                 Greenland           Fruits       Offline
# 79   North America  United States of America  Office Supplies        Online
# 100  North America  United States of America          Clothes       Offline
# 177  North America                    Mexico          Clothes        Online
# 191  North America  United States of America        Baby Food       Offline
# 193  North America                    Canada       Vegetables       Offline
# 311  North America                 Greenland        Household        Online
# 318  North America                 Greenland        Baby Food       Offline
# 332  North America  United States of America        Beverages        Online
# ...

# %%
#least common item type
least_common_item_type = df_sales_records['Item Type'].value_counts().idxmin()

print(least_common_item_type)
# Out:
# Fruits

# %%
item_counts = df_sales_records['Item Type'].value_counts()
least_common_item = item_counts.idxmin()

print(f"The least common item type is: {least_common_item}")
# Out:
# The least common item type is: Fruits

# %%
#Most common item type
most_common_item_type = df_sales_records['Item Type'].value_counts().idxmax()

print(most_common_item_type)
# Out:
# Beverages

# %%
most_common_item = item_counts.idxmax()

print(f"The most common item type is: {most_common_item}")
# Out:
# The most common item type is: Beverages
